# %% [markdown]
# ### Importing Packages

# %%
import pandas as pd
import mysql.connector

# %% [markdown]
# ### Opening a Local JSON File

# %%
pd.read_json("./train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# ### Opening a JSON File from URL

# %%
pd.read_json("https://api.exchangerate-api.com/v4/latest/PKR")

# %% [markdown]
# ### Connecting to SQL Database

# %%
con = mysql.connector.connect(host="localhost", user="root", password="", database="world")

# %%
pd.read_sql_query("SELECT * FROM country WHERE name='Pakistan';",con)
# Out:
# C:\Users\Muhammad Abdullah\AppData\Local\Temp\ipykernel_12196\3120426176.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE name='Pakistan';",con)
#   Code      Name Continent                     Region  SurfaceArea  IndepYear  \
# 0  PAK  Pakistan      Asia  Southern and Central Asia     796095.0       1947
#
#    Population  LifeExpectancy      GNP   GNPOld LocalName GovernmentForm  \
# 0   156483000            61.1  61289.0  58549.0  Pakistan       Republic
#
#             HeadOfState  Capital Code2
# 0  Mohammad Rafiq Tarar     2831    PK

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode='PAK';",con)
# Out:
# C:\Users\Muhammad Abdullah\AppData\Local\Temp\ipykernel_12196\760215163.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode='PAK';",con)
#       ID              Name CountryCode              District  Population
# 0   2822           Karachi         PAK                 Sindh     9269265
# 1   2823            Lahore         PAK                Punjab     5063499
# 2   2824        Faisalabad         PAK                Punjab     1977246
# 3   2825        Rawalpindi         PAK                Punjab     1406214
# 4   2826            Multan         PAK                Punjab     1182441
# 5   2827         Hyderabad         PAK                 Sindh     1151274
# 6   2828        Gujranwala         PAK                Punjab     1124749
# ...

# %%
pd.read_sql_query("SELECT * FROM countryLanguage;",con)
# Out:
# C:\Users\Muhammad Abdullah\AppData\Local\Temp\ipykernel_12196\694951135.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM countryLanguage;",con)
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# ...
